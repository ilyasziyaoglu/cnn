# %%
from matplotlib import pyplot as plt
from PIL import Image as im
import numpy as np
import math

# %%
def prepare_filter(n):
    cell = 1/math.pow(n, 2)
    
    filt = []
    for i in range(n):
        filt.append([])
        for j in range(n):
            filt[i].append(cell)
    
    return filt

# %%
# FILTERS

#identity
birim_filt = [[0,0,0],
        [0,1,0],
        [0,0,0]]

#edge detection
edge_filt1 = [[1,0,-1],
        [0,0,0],
        [-1,0,1]]

edge_filt2 = np.array([[0,1,0],
        [1,-4,1],
        [0,1,0]])

edge_filt3 = np.array([[-1,-1,-1],
        [-1,8,-1],
        [-1,-1,-1]])

#sharpen
filt5 = [[0,-1,0],
        [-1,5,-1],
        [0,-1,0]]

#box-blur
filt6 = prepare_filter(3)

#gaussian blur 3x3
gaussianblur3_filt = [[1,2,1],
        [2,4,2],
        [1,2,1]]
filt7 = np.multiply(gaussianblur3_filt, 1/16)

#gaussian blur 5x5
gaussianblur5_filt = [
    [1,4,6,4,1],
    [4,16,24,16,4],
    [6,24,36,24,6],
    [4,16,24,16,4],
    [1,4,6,4,1],
]
filt8 = np.multiply(gaussianblur5_filt, 1/256)

#unsharp masking 5x5
unsharp_filt = [
    [1,4,6,4,1],
    [4,16,24,16,4],
    [6,24,-476,24,6],
    [4,16,24,16,4],
    [1,4,6,4,1],
]
filt9 = np.multiply(unsharp_filt, 1/256)

#keskinlestirme filtresi
filtre_keskinlestirme = [
    [0,-2,0],
    [-2,11,-2],
    [0,-2,0]
]

# %%
def convolution(img, filt_size):
    shape = img.shape
    if len(shape)==2:
        newimg = edge_filt3 #np.zeros((shape[0]-(filt_size - 1), shape[1] - (filt_size - 1)))
        filt = np.random.randint(-3, 4, (filt_size, filt_size))

        for i in range(shape[0]-filt_size+1):
            for j in range(shape[1]-filt_size+1):
                temp = img[i:i+filt_size,j:j+filt_size]
                newimg[i,j] = np.sum(np.multiply(temp, filt))
    else:
        newimg = np.zeros((shape[0]-(filt_size - 1), shape[1] - (filt_size - 1), shape[2]))
        filt = edge_filt3 #np.random.randint(-3, 4, (filt_size, filt_size))

        for i in range(shape[0]-filt_size+1):
            for j in range(shape[1]-filt_size+1):
                for k in range(shape[2]):
                    temp = img[i:i+filt_size,j:j+filt_size,k]
                    newimg[i,j,k] = np.sum(np.multiply(temp, filt))
    
    return newimg

# %%
def relu(img):
    shape = img.shape
    if len(shape)==2:
        for i in range(shape[0]):
            for j in range(shape[1]):
                img[i, j] = np.max([0, img[i, j]])
    else:
        for i in range(shape[0]):
            for j in range(shape[1]):
                for k in range(shape[2]):
                    img[i, j, k] = np.max([0, img[i, j, k]])
    
    return img

# %%
def maxPooling(img, pool_size):
    shape = img.shape
    if len(shape)==2:
        newimg = np.zeros((math.ceil(shape[0]/pool_size), math.ceil(shape[1]/pool_size)))

        for i,m in zip(range(0, shape[0], pool_size), range(round(shape[0]/pool_size))):
            for j,n in zip(range(0, shape[1], pool_size), range(round(shape[1]/pool_size))):
                newimg[m, n] = np.max(img[i:i+pool_size, j:j+pool_size])
    else:
        newimg = np.zeros((math.ceil(shape[0]/pool_size), math.ceil(shape[1]/pool_size), shape[2]))

        for i,m in zip(range(0, shape[0], pool_size), range(round(shape[0]/pool_size))):
            for j,n in zip(range(0, shape[1], pool_size), range(round(shape[1]/pool_size))):
                for k in range(shape[2]):
                    newimg[m, n, k] = np.max(img[i:i+pool_size, j:j+pool_size, k])
    
    return newimg

# %%
image = im.open('ucak.jpg')
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=972x648 at 0x2A66DBDCCF8>

# %%
img = np.array(image)

# %%
conv = convolution(img, 3)

# %%
print(np.max(conv))
print(np.min(conv))
# Out:
# 1426.0
# -928.0

# %%
rel = relu(conv)

# %%
print(np.max(rel))
print(np.min(rel))
# Out:
# 1426.0
# 0.0

# %%
pool = maxPooling(img, 2)

# %%
print(np.max(pool))
print(np.min(pool))
# Out:
# 255.0
# 0.0

# %%
rgb = im.fromarray(conv, 'RGB')
rgb
# Out:
# <PIL.Image.Image image mode=RGB size=970x646 at 0x2A66DC825C0>

# %%
rgb = im.fromarray(rel, 'RGB')
rgb
# Out:
# <PIL.Image.Image image mode=RGB size=970x646 at 0x2A66DC82A20>

# %%
rgb = im.fromarray(pool, 'RGB')
rgb
# Out:
# <PIL.Image.Image image mode=RGB size=486x324 at 0x2A66DC82DD8>

# %%
plt.imshow(conv)

# %%
plt.imshow(rel)

# %%
plt.imshow(pool)

# %%
from PIL import Image
from PIL import ImageFilter
from PIL.ImageFilter import (
    BLUR, CONTOUR, DETAIL, EDGE_ENHANCE, EDGE_ENHANCE_MORE,
    EMBOSS, FIND_EDGES, SMOOTH, SMOOTH_MORE, SHARPEN
    )

# %%
image = image.convert('L')

# %%
km = np.array((
        (1, 4, 6, 4, 1),
        (4, 16, 24, 16, 4),
        (6, 24, 36, 24, 6),
        (4, 16, 24, 16, 4),
        (1, 4, 6, 4, 1),
      )) / 256

k = ImageFilter.Kernel(
    size=km.shape,
    kernel=km.flatten(),
    scale=sum(km),  # default
    offset=0  # default
    )

# %%
image.filter(k)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-47d9686b3076> in <module>
# ----> 1 image.filter(k)
#
# c:\users\babek\appdata\local\programs\python\python36\lib\site-packages\PIL\Image.py in filter(self, filter)
#    1203         multiband = isinstance(filter, ImageFilter.MultibandFilter)
#    1204         if self.im.bands == 1 or multiband:
# -> 1205             return self._new(filter.filter(self.im))
#    1206
#    1207         ims = []
#
# c:\users\babek\appdata\local\programs\python\python36\lib\site-packages\PIL\ImageFilter.py in filter(self, image)
#      38         if image.mode == "P":
#      39             raise ValueError("cannot filter palette images")
# ---> 40         return image.filter(*self.filterargs)
#      41
#      42
#
# TypeError: only size-1 arrays can be converted to Python scalars
